# %%
import itertools as it

#C1 - C2 - C4 - C6
X = {0, 18}
Y = {0, 40}
Z = {0, 9}
set(it.product(X, Y, Z))
# Out:
# {(0, 0, 0),
#  (0, 0, 9),
#  (0, 40, 0),
#  (0, 40, 9),
#  (18, 0, 0),
#  (18, 0, 9),
#  (18, 40, 0),
#  (18, 40, 9)}

# %%
import itertools as it

#C1 - C2 - C4 - C5 - C6
X = {0, 18}
Y = {0, 40}
Z = {0, 12}
M = {0, 36}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 36),
#  (0, 0, 12, 0),
#  (0, 0, 12, 36),
#  (0, 40, 0, 0),
#  (0, 40, 0, 36),
#  (0, 40, 12, 0),
#  (0, 40, 12, 36),
#  (18, 0, 0, 0),
#  (18, 0, 0, 36),
#  (18, 0, 12, 0),
#  (18, 0, 12, 36),
#  (18, 40, 0, 0),
#  (18, 40, 0, 36),
#  (18, 40, 12, 0),
#  (18, 40, 12, 36)}

# %%
import itertools as it

#C1 - C2 - C4 - C3 - C5 - C6
X = {0, 18}
Y = {0, 40}
Z = {0, 12}
M = {0, 12}
N = {0, 36}
set(it.product(X, Y, Z, M, N))
# Out:
# {(0, 0, 0, 0, 0),
#  (0, 0, 0, 0, 36),
#  (0, 0, 0, 12, 0),
#  (0, 0, 0, 12, 36),
#  (0, 0, 12, 0, 0),
#  (0, 0, 12, 0, 36),
#  (0, 0, 12, 12, 0),
#  (0, 0, 12, 12, 36),
#  (0, 40, 0, 0, 0),
#  (0, 40, 0, 0, 36),
#  (0, 40, 0, 12, 0),
#  (0, 40, 0, 12, 36),
#  (0, 40, 12, 0, 0),
#  (0, 40, 12, 0, 36),
#  (0, 40, 12, 12, 0),
#  (0, 40, 12, 12, 36),
#  (18, 0, 0, 0, 0),
#  (18, 0, 0, 0, 36),
#  (18, 0, 0, 12, 0),
#  (18, 0, 0, 12, 36),
#  (18, 0, 12, 0, 0),
#  (18, 0, 12, 0, 36),
#  (18, 0, 12, 12, 0),
#  (18, 0, 12, 12, 36),
#  (18, 40, 0, 0, 0),
#  (18, 40, 0, 0, 36),
#  (18, 40, 0, 12, 0),
#  (18, 40, 0, 12, 36),
#  (18, 40, 12, 0, 0),
#  (18, 40, 12, 0, 36),
#  (18, 40, 12, 12, 0),
#  (18, 40, 12, 12, 36)}

# %%
import itertools as it

#C1 - C2 - C3 - C4 - C5 - C6
X = {0, 18}
Y = {0, 8}
Z = {0, 12}
M = {0, 12}
N = {0, 36}
set(it.product(X, Y, Z, M, N))
# Out:
# {(0, 0, 0, 0, 0),
#  (0, 0, 0, 0, 36),
#  (0, 0, 0, 12, 0),
#  (0, 0, 0, 12, 36),
#  (0, 0, 12, 0, 0),
#  (0, 0, 12, 0, 36),
#  (0, 0, 12, 12, 0),
#  (0, 0, 12, 12, 36),
#  (0, 8, 0, 0, 0),
#  (0, 8, 0, 0, 36),
#  (0, 8, 0, 12, 0),
#  (0, 8, 0, 12, 36),
#  (0, 8, 12, 0, 0),
#  (0, 8, 12, 0, 36),
#  (0, 8, 12, 12, 0),
#  (0, 8, 12, 12, 36),
#  (18, 0, 0, 0, 0),
#  (18, 0, 0, 0, 36),
#  (18, 0, 0, 12, 0),
#  (18, 0, 0, 12, 36),
#  (18, 0, 12, 0, 0),
#  (18, 0, 12, 0, 36),
#  (18, 0, 12, 12, 0),
#  (18, 0, 12, 12, 36),
#  (18, 8, 0, 0, 0),
#  (18, 8, 0, 0, 36),
#  (18, 8, 0, 12, 0),
#  (18, 8, 0, 12, 36),
#  (18, 8, 12, 0, 0),
#  (18, 8, 12, 0, 36),
#  (18, 8, 12, 12, 0),
#  (18, 8, 12, 12, 36)}

# %%
import itertools as it

#C1 - C2 - C3 - C5 - C6
X = {0, 18}
Y = {0, 8}
Z = {0, 12}
M = {0, 36}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 36),
#  (0, 0, 12, 0),
#  (0, 0, 12, 36),
#  (0, 8, 0, 0),
#  (0, 8, 0, 36),
#  (0, 8, 12, 0),
#  (0, 8, 12, 36),
#  (18, 0, 0, 0),
#  (18, 0, 0, 36),
#  (18, 0, 12, 0),
#  (18, 0, 12, 36),
#  (18, 8, 0, 0),
#  (18, 8, 0, 36),
#  (18, 8, 12, 0),
#  (18, 8, 12, 36)}

# %%
import itertools as it

#C1 - C2 - C3 - C4 - C6 
X = {0, 18}
Y = {0, 8}
Z = {0, 12}
M = {0, 9}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 9),
#  (0, 0, 12, 0),
#  (0, 0, 12, 9),
#  (0, 8, 0, 0),
#  (0, 8, 0, 9),
#  (0, 8, 12, 0),
#  (0, 8, 12, 9),
#  (18, 0, 0, 0),
#  (18, 0, 0, 9),
#  (18, 0, 12, 0),
#  (18, 0, 12, 9),
#  (18, 8, 0, 0),
#  (18, 8, 0, 9),
#  (18, 8, 12, 0),
#  (18, 8, 12, 9)}

# %%
import itertools as it

#C1 - C3 - C5 - C6 
X = {0, 9}
Y = {0, 12}
Z = {0, 36}
set(it.product(X, Y, Z))
# Out:
# {(0, 0, 0),
#  (0, 0, 36),
#  (0, 12, 0),
#  (0, 12, 36),
#  (9, 0, 0),
#  (9, 0, 36),
#  (9, 12, 0),
#  (9, 12, 36)}

# %%
import itertools as it

#C1 - C3 - C4 - C5 - C6
X = {0, 9}
Y = {0, 12}
Z = {0, 12}
M = {0, 36}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 36),
#  (0, 0, 12, 0),
#  (0, 0, 12, 36),
#  (0, 12, 0, 0),
#  (0, 12, 0, 36),
#  (0, 12, 12, 0),
#  (0, 12, 12, 36),
#  (9, 0, 0, 0),
#  (9, 0, 0, 36),
#  (9, 0, 12, 0),
#  (9, 0, 12, 36),
#  (9, 12, 0, 0),
#  (9, 12, 0, 36),
#  (9, 12, 12, 0),
#  (9, 12, 12, 36)}

# %%
import itertools as it

#C1 - C3 - C4 - C6
X = {0, 9}
Y = {0, 12}
Z = {0, 9}
set(it.product(X, Y, Z))
# Out:
# {(0, 0, 0),
#  (0, 0, 9),
#  (0, 12, 0),
#  (0, 12, 9),
#  (9, 0, 0),
#  (9, 0, 9),
#  (9, 12, 0),
#  (9, 12, 9)}

# %%
import itertools as it

#C1 - C3 - C2 - C4 - C6
X = {0, 9}
Y = {0, 8}
Z = {0, 40}
M = {0, 9}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 9),
#  (0, 0, 40, 0),
#  (0, 0, 40, 9),
#  (0, 8, 0, 0),
#  (0, 8, 0, 9),
#  (0, 8, 40, 0),
#  (0, 8, 40, 9),
#  (9, 0, 0, 0),
#  (9, 0, 0, 9),
#  (9, 0, 40, 0),
#  (9, 0, 40, 9),
#  (9, 8, 0, 0),
#  (9, 8, 0, 9),
#  (9, 8, 40, 0),
#  (9, 8, 40, 9)}

# %%
import itertools as it

#C1 - C3 - C2 - C4 - C5 - C6
X = {0, 9}
Y = {0, 8}
Z = {0, 40}
M = {0, 12}
N = {0, 36}
set(it.product(X, Y, Z, M, N))
# Out:
# {(0, 0, 0, 0, 0),
#  (0, 0, 0, 0, 36),
#  (0, 0, 0, 12, 0),
#  (0, 0, 0, 12, 36),
#  (0, 0, 40, 0, 0),
#  (0, 0, 40, 0, 36),
#  (0, 0, 40, 12, 0),
#  (0, 0, 40, 12, 36),
#  (0, 8, 0, 0, 0),
#  (0, 8, 0, 0, 36),
#  (0, 8, 0, 12, 0),
#  (0, 8, 0, 12, 36),
#  (0, 8, 40, 0, 0),
#  (0, 8, 40, 0, 36),
#  (0, 8, 40, 12, 0),
#  (0, 8, 40, 12, 36),
#  (9, 0, 0, 0, 0),
#  (9, 0, 0, 0, 36),
#  (9, 0, 0, 12, 0),
#  (9, 0, 0, 12, 36),
#  (9, 0, 40, 0, 0),
#  (9, 0, 40, 0, 36),
#  (9, 0, 40, 12, 0),
#  (9, 0, 40, 12, 36),
#  (9, 8, 0, 0, 0),
#  (9, 8, 0, 0, 36),
#  (9, 8, 0, 12, 0),
#  (9, 8, 0, 12, 36),
#  (9, 8, 40, 0, 0),
#  (9, 8, 40, 0, 36),
#  (9, 8, 40, 12, 0),
#  (9, 8, 40, 12, 36)}

# %%
import itertools as it

#C1 - C3 - C5 - C4 - C6
X = {0, 9}
Y = {0, 12}
Z = {0, 12}
M = {0, 9}
set(it.product(X, Y, Z, M))
# Out:
# {(0, 0, 0, 0),
#  (0, 0, 0, 9),
#  (0, 0, 12, 0),
#  (0, 0, 12, 9),
#  (0, 12, 0, 0),
#  (0, 12, 0, 9),
#  (0, 12, 12, 0),
#  (0, 12, 12, 9),
#  (9, 0, 0, 0),
#  (9, 0, 0, 9),
#  (9, 0, 12, 0),
#  (9, 0, 12, 9),
#  (9, 12, 0, 0),
#  (9, 12, 0, 9),
#  (9, 12, 12, 0),
#  (9, 12, 12, 9)}

# %%
import itertools as it

#C1 - C2 - C3 - C5 - C4 - C6
X = {0, 18}
Y = {0, 8}
Z = {0, 12}
M = {0, 12}
N = {0, 9}
set(it.product(X, Y, Z, M, N))
# Out:
# {(0, 0, 0, 0, 0),
#  (0, 0, 0, 0, 9),
#  (0, 0, 0, 12, 0),
#  (0, 0, 0, 12, 9),
#  (0, 0, 12, 0, 0),
#  (0, 0, 12, 0, 9),
#  (0, 0, 12, 12, 0),
#  (0, 0, 12, 12, 9),
#  (0, 8, 0, 0, 0),
#  (0, 8, 0, 0, 9),
#  (0, 8, 0, 12, 0),
#  (0, 8, 0, 12, 9),
#  (0, 8, 12, 0, 0),
#  (0, 8, 12, 0, 9),
#  (0, 8, 12, 12, 0),
#  (0, 8, 12, 12, 9),
#  (18, 0, 0, 0, 0),
#  (18, 0, 0, 0, 9),
#  (18, 0, 0, 12, 0),
#  (18, 0, 0, 12, 9),
#  (18, 0, 12, 0, 0),
#  (18, 0, 12, 0, 9),
#  (18, 0, 12, 12, 0),
#  (18, 0, 12, 12, 9),
#  (18, 8, 0, 0, 0),
#  (18, 8, 0, 0, 9),
#  (18, 8, 0, 12, 0),
#  (18, 8, 0, 12, 9),
#  (18, 8, 12, 0, 0),
#  (18, 8, 12, 0, 9),
#  (18, 8, 12, 12, 0),
#  (18, 8, 12, 12, 9)}
